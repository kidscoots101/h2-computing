# %%
# Task 4.1

import sqlite3

conn = sqlite3.connect('library.db')

conn.execute(
'''
CREATE TABLE "Book" (
	"BookID"	INTEGER PRIMARY KEY,
	"Title"	TEXT,
	"Genre"	TEXT
);
CREATE TABLE "Member" (
	"MemberName"	TEXT,
	"FamilyName"	TEXT,
	"GivenName"	TEXT,
	PRIMARY KEY("MemberName")
);
CREATE TABLE Loan
'''
)
